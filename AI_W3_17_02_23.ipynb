# %% [markdown]
# <a href="https://colab.research.google.com/github/daiduong101202/AI--ChieuT6/blob/main/AI_W3_17_02_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#load library

# %%
import pandas as pd

# %%
#create dataframe

# %%
dataframe = pd.DataFrame()

# %%
#add colums

# %%
dataframe['Name'] = ['Lemon','Apple', 'Banana']

# %%
dataframe['Price']= [5,8,7]

# %%
dataframe['License']=[False,True, True]

# %%
#show data

# %%
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
dataframe.shape
# Out:
# (3, 3)

# %%
df=dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     3 non-null      object
#  1   Price    3 non-null      int64
#  2   License  3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 179.0+ bytes

# %%
#print column name

# %%
list(df.columns)
# Out:
# ['Name', 'Price', 'License']

# %%
#loc iloc

# %%
df.loc[(df.Price==5)]
# Out:
#     Name  Price  License
# 0  Lemon      5    False

# %%
df.loc[(df.Price==5)|(df.Name=='Banana')]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 2  Banana      7     True

# %%
df.loc[(df.Price==5)|(df.Name=='Banana'),['Name','Price']]
# Out:
#      Name  Price
# 0   Lemon      5
# 2  Banana      7

# %%
df.iloc[[2]]
# Out:
#      Name  Price  License
# 2  Banana      7     True

# %%
type(df.iloc[2])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0:2]
# Out:
#     Name  Price  License
# 0  Lemon      5    False
# 1  Apple      8     True

# %%
df.iloc[0:3]
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
df.iloc[0:2,0:-1]
# Out:
#     Name  Price
# 0  Lemon      5
# 1  Apple      8

# %%
df.iloc[0:2,-1]
# Out:
# 0    False
# 1     True
# Name: License, dtype: bool

# %%
df.iloc[0:3,-1]
# Out:
# 0    False
# 1     True
# 2     True
# Name: License, dtype: bool

# %%
sum=df.Price.sum()

# %%
print(sum)
# Out:
# 20

# %%
count=df['Price'].count()

# %%
print(count)
# Out:
# 3

# %%
#create row data
new = pd.Series(['Orange',10,True], index=['Name','Price','License'])
#append row
dataframe.append(new,ignore_index=True)
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True
# 3  Orange     10     True

# %%
dataframe
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
#append a column
dataframe['Location']=['USA','VN','SIN']
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN

# %%
#delete a row
dataframe.drop(1,axis=0).head(10)
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 2  Banana      7     True      SIN

# %%
#delete a column
dataframe.drop('Location',axis=1).head()
# Out:
#      Name  Price  License
# 0   Lemon      5    False
# 1   Apple      8     True
# 2  Banana      7     True

# %%
#replace
dataframe['Price'].replace(5,7).head(10)
# Out:
# 0    7
# 1    8
# 2    7
# Name: Price, dtype: int64

# %%
dataframe
# Out:
#      Name  Price  License Location
# 0   Lemon      5    False      USA
# 1   Apple      8     True       VN
# 2  Banana      7     True      SIN

# %%
#rename column
dataframe.rename(columns={'Price':'Cost'}).head()
# Out:
#      Name  Cost  License Location
# 0   Lemon     5    False      USA
# 1   Apple     8     True       VN
# 2  Banana     7     True      SIN

# %%
#2 Knowing data

# %%
# load library
import pandas as pd
# create url
url = 'http://winterolympicsmedals.com/medals.csv'
# load data
dataframe = pd.read_csv(url)
# show data
dataframe.head()
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
dataframe
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# 3               M  Bronze
# 4               M    Gold
# ...           ...     ...
# 2306            M  Silver
# 2307            W    Gold
# 2308            W  Silver
# 2309            M    Gold
# 2310            W  Silver
#
# [2311 rows x 8 columns]

# %%
dataframe.shape
# Out:
# (2311, 8)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2311 entries, 0 to 2310
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Year          2311 non-null   int64
#  1   City          2311 non-null   object
#  2   Sport         2311 non-null   object
#  3   Discipline    2311 non-null   object
#  4   NOC           2311 non-null   object
#  5   Event         2311 non-null   object
#  6   Event gender  2311 non-null   object
#  7   Medal         2311 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 144.6+ KB

# %%
data=dataframe

# %%
data.describe()
# std: phuong sai
# mean: gia tri trung binh
# Out:
#               Year
# count  2311.000000
# mean   1980.361748
# std      22.089091
# min    1924.000000
# 25%    1968.000000
# 50%    1988.000000
# 75%    1998.000000
# max    2006.000000

# %%
data.iloc[0:10] # ~[:10]
# Out:
#    Year      City       Sport      Discipline  NOC            Event  \
# 0  1924  Chamonix     Skating  Figure skating  AUT       individual
# 1  1924  Chamonix     Skating  Figure skating  AUT       individual
# 2  1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# 5  1924  Chamonix    Biathlon        Biathlon  FIN  military patrol
# 6  1924  Chamonix     Skating  Figure skating  FIN            pairs
# 7  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 8  1924  Chamonix     Skating   Speed skating  FIN           10000m
# 9  1924  Chamonix     Skating   Speed skating  FIN            1500m
#
#   Event gender   Medal
# 0            M  Silver
# 1            W    Gold
# 2            X    Gold
# 3            M  Bronze
# 4            M    Gold
# 5            M  Silver
# 6            X  Silver
# 7            M    Gold
# 8            M  Silver
# 9            M    Gold

# %%
data.iloc[[200,]]
# Out:
#      Year        City   Sport       Discipline  NOC       Event Event gender  \
# 200  1948  St. Moritz  Skiing  Nordic Combined  FIN  individual            M
#
#     Medal
# 200  Gold

# %%
data.iloc[[120,]]
# Out:
#      Year         City      Sport Discipline  NOC     Event Event gender Medal
# 120  1932  Lake Placid  Bobsleigh  Bobsleigh  USA  four-man            M  Gold

# %%
data=data.set_index(data['NOC'])

# %%
data.loc['GER']
# Out:
#      Year                    City       Sport       Discipline  NOC  \
# NOC
# GER  1928              St. Moritz   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid   Bobsleigh        Bobsleigh  GER
# GER  1932             Lake Placid  Ice Hockey       Ice Hockey  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# GER  1936  Garmisch-Partenkirchen     Skating   Figure skating  GER
# ..    ...                     ...         ...              ...  ...
# GER  2006                   Turin      Skiing  Cross Country S  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing  Nordic Combined  GER
# GER  2006                   Turin      Skiing        Snowboard  GER
#
#                      Event Event gender   Medal
# NOC
# GER               five-man            M  Bronze
# GER               four-man            M  Bronze
# GER             ice hockey            M  Bronze
# GER             individual            M  Silver
# GER                  pairs            X    Gold
# ..                     ...          ...     ...
# GER           sprint 1.5km            W  Silver
# GER             Individual            M    Gold
# GER      Individual sprint            M  Bronze
# GER                   Team            M  Silver
# GER  Giant parallel slalom            W  Silver
#
# [158 rows x 8 columns]

# %%
data[(data['Year']>=1990)&(data['Year']<=2000) & (data['NOC']=='USA')&(data['Event gender']=='W')&(data['Medal']=='Gold')].head(15)
# Out:
#      Year         City       Sport      Discipline  NOC       Event  \
# NOC
# USA  1992  Albertville     Skating  Figure skating  USA  individual
# USA  1992  Albertville     Skating  Short Track S.  USA        500m
# USA  1992  Albertville     Skating   Speed skating  USA       1000m
# USA  1992  Albertville     Skating   Speed skating  USA        500m
# USA  1992  Albertville      Skiing  Freestyle Ski.  USA      moguls
# USA  1994  Lillehammer     Skating  Short Track S.  USA        500m
# USA  1994  Lillehammer     Skating   Speed skating  USA       1000m
# USA  1994  Lillehammer     Skating   Speed skating  USA        500m
# USA  1994  Lillehammer      Skiing   Alpine Skiing  USA     super-G
# USA  1998       Nagano  Ice Hockey      Ice Hockey  USA  ice hockey
# USA  1998       Nagano     Skating  Figure skating  USA  individual
# USA  1998       Nagano      Skiing   Alpine Skiing  USA     super-G
# USA  1998       Nagano      Skiing  Freestyle Ski.  USA     aerials
#
#     Event gender Medal
# NOC
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold
# USA            W  Gold

# %%
data['NOC'].value_counts()
# Out:
# NOR    280
# USA    216
# URS    194
# AUT    185
# GER    158
# FIN    151
# CAN    119
# SUI    118
# SWE    118
# GDR    110
# ITA    101
# FRA     83
# NED     78
# RUS     76
# FRG     41
# CHN     33
# JPN     32
# KOR     31
# TCH     25
# EUN     23
# GBR     21
# EUA     19
# CZE     10
# LIE      9
# POL      8
# CRO      7
# BUL      6
# EST      6
# AUS      6
# BLR      6
# HUN      6
# UKR      5
# BEL      5
# KAZ      5
# YUG      4
# SLO      4
# ESP      2
# PRK      2
# LUX      2
# LAT      1
# ROU      1
# DEN      1
# UZB      1
# NZL      1
# SVK      1
# Name: NOC, dtype: int64

# %%
data['NOC'].count()
# Out:
# 2311

# %%
data['NOC'].unique()
# Out:
# array(['AUT', 'BEL', 'CAN', 'FIN', 'FRA', 'GBR', 'NOR', 'SUI', 'SWE',
#        'USA', 'GER', 'TCH', 'HUN', 'ITA', 'FRG', 'NED', 'EUA', 'JPN',
#        'POL', 'URS', 'PRK', 'GDR', 'ROU', 'ESP', 'LIE', 'BUL', 'YUG',
#        'CHN', 'EUN', 'KOR', 'LUX', 'NZL', 'AUS', 'BLR', 'KAZ', 'RUS',
#        'SLO', 'UKR', 'UZB', 'CZE', 'DEN', 'CRO', 'EST', 'LAT', 'SVK'],
#       dtype=object)

# %%
data.drop('City', axis=1).head(10)
# Out:
#      Year       Sport      Discipline  NOC            Event Event gender  \
# NOC
# AUT  1924     Skating  Figure skating  AUT       individual            M
# AUT  1924     Skating  Figure skating  AUT       individual            W
# AUT  1924     Skating  Figure skating  AUT            pairs            X
# BEL  1924   Bobsleigh       Bobsleigh  BEL         four-man            M
# CAN  1924  Ice Hockey      Ice Hockey  CAN       ice hockey            M
# FIN  1924    Biathlon        Biathlon  FIN  military patrol            M
# FIN  1924     Skating  Figure skating  FIN            pairs            X
# FIN  1924     Skating   Speed skating  FIN           10000m            M
# FIN  1924     Skating   Speed skating  FIN           10000m            M
# FIN  1924     Skating   Speed skating  FIN            1500m            M
#
#       Medal
# NOC
# AUT  Silver
# AUT    Gold
# AUT    Gold
# BEL  Bronze
# CAN    Gold
# FIN  Silver
# FIN  Silver
# FIN    Gold
# FIN  Silver
# FIN    Gold

# %%
data.drop(data.columns[2:4], axis=1).head(10)
# Out:
#      Year      City  NOC            Event Event gender   Medal
# NOC
# AUT  1924  Chamonix  AUT       individual            M  Silver
# AUT  1924  Chamonix  AUT       individual            W    Gold
# AUT  1924  Chamonix  AUT            pairs            X    Gold
# BEL  1924  Chamonix  BEL         four-man            M  Bronze
# CAN  1924  Chamonix  CAN       ice hockey            M    Gold
# FIN  1924  Chamonix  FIN  military patrol            M  Silver
# FIN  1924  Chamonix  FIN            pairs            X  Silver
# FIN  1924  Chamonix  FIN           10000m            M    Gold
# FIN  1924  Chamonix  FIN           10000m            M  Silver
# FIN  1924  Chamonix  FIN            1500m            M    Gold

# %%
data.groupby('NOC').count

# %%
#apply a function
def uppercase(x):
  return x.upper()
data['Event'].apply(uppercase)[0:2311]
# Out:
# NOC
# AUT         INDIVIDUAL
# AUT         INDIVIDUAL
# AUT              PAIRS
# BEL           FOUR-MAN
# CAN         ICE HOCKEY
#             ...
# USA          HALF-PIPE
# USA          HALF-PIPE
# USA          HALF-PIPE
# USA    SNOWBOARD CROSS
# USA    SNOWBOARD CROSS
# Name: Event, Length: 2311, dtype: object

# %%
data
# Out:
#      Year      City       Sport      Discipline  NOC            Event  \
# NOC
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT       individual
# AUT  1924  Chamonix     Skating  Figure skating  AUT            pairs
# BEL  1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# CAN  1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ..    ...       ...         ...             ...  ...              ...
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# USA  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# USA  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#     Event gender   Medal
# NOC
# AUT            M  Silver
# AUT            W    Gold
# AUT            X    Gold
# BEL            M  Bronze
# CAN            M    Gold
# ..           ...     ...
# USA            M  Silver
# USA            W    Gold
# USA            W  Silver
# USA            M    Gold
# USA            W  Silver
#
# [2311 rows x 8 columns]
