# %% [markdown]
# <a href="https://colab.research.google.com/github/daiduong101202/AI--ChieuT6/blob/main/Medical_Diagnosis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 22.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=c91fb97e7d087e7aabe897a7b51c2b038276b340152aefc45939b7d2dd9aeecd
#   Stored in directory: /root/.cache/pip/wheels/32/2c/a1/a90a7d7dd8448ec029f298a61f3490275e99b17aa348be675c
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
fever=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'fever')
headache=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'headache')
nausea=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'nausea')
vomiting=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'vomiting')
jaundice=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'jaundice')
enlarge_liver=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'enlarge liver')
joint_pain=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'joint pain')
body_weakness=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'body weakness')
dizziness=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'dizziness')
loss_of_appetite=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'loss of appetite')
mp=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'mp')
malaria_fever=ctrl.Antecedent(np.arange(0.1,1.1,0.1),'malaria fever')

fever['minor']=fuzz.trimf(fever.universe,[0.1,0.2,0.3])
fever['moderate']=fuzz.trimf(fever.universe,[0.3,0.5,0.6])
fever['severe']=fuzz.trimf(fever.universe,[0.6,0.7,0.8])
fever['very severe']=fuzz.trimf(fever.universe,[0.8,0.9,1])

headache['minor']=fuzz.trimf(headache.universe,[0.1,0.2,0.3])
headache['moderate']=fuzz.trimf(headache.universe,[0.3,0.5,0.6])
headache['severe']=fuzz.trimf(headache.universe,[0.6,0.7,0.8])
headache['very severe']=fuzz.trimf(headache.universe,[0.8,0.9,1])

nausea['minor']=fuzz.trimf(nausea.universe,[0.1,0.2,0.3])
nausea['moderate']=fuzz.trimf(nausea.universe,[0.3,0.5,0.6])
nausea['severe']=fuzz.trimf(nausea.universe,[0.6,0.7,0.8])
nausea['very severe']=fuzz.trimf(nausea.universe,[0.8,0.9,1])

vomiting['minor']=fuzz.trimf(vomiting.universe,[0.1,0.2,0.3])
vomiting['moderate']=fuzz.trimf(vomiting.universe,[0.3,0.5,0.6])
vomiting['severe']=fuzz.trimf(vomiting.universe,[0.6,0.7,0.8])
vomiting['very severe']=fuzz.trimf(vomiting.universe,[0.8,0.9,1])

jaundice['minor']=fuzz.trimf(jaundice.universe,[0.1,0.2,0.3])
jaundice['moderate']=fuzz.trimf(jaundice.universe,[0.3,0.5,0.6])
jaundice['severe']=fuzz.trimf(jaundice.universe,[0.6,0.7,0.8])
jaundice['very severe']=fuzz.trimf(jaundice.universe,[0.8,0.9,1])

enlarge_liver['minor']=fuzz.trimf(enlarge_liver.universe,[0.1,0.2,0.3])
enlarge_liver['moderate']=fuzz.trimf(enlarge_liver.universe,[0.3,0.5,0.6])
enlarge_liver['severe']=fuzz.trimf(enlarge_liver.universe,[0.6,0.7,0.8])
enlarge_liver['very severe']=fuzz.trimf(enlarge_liver.universe,[0.8,0.9,1])

joint_pain['minor']=fuzz.trimf(joint_pain.universe,[0.1,0.2,0.3])
joint_pain['moderate']=fuzz.trimf(joint_pain.universe,[0.3,0.5,0.6])
joint_pain['severe']=fuzz.trimf(joint_pain.universe,[0.6,0.7,0.8])
joint_pain['very severe']=fuzz.trimf(joint_pain.universe,[0.8,0.9,1])

body_weakness['minor']=fuzz.trimf(body_weakness.universe,[0.1,0.2,0.3])
body_weakness['moderate']=fuzz.trimf(body_weakness.universe,[0.3,0.5,0.6])
body_weakness['severe']=fuzz.trimf(body_weakness.universe,[0.6,0.7,0.8])
body_weakness['very severe']=fuzz.trimf(body_weakness.universe,[0.8,0.9,1])

dizziness['minor']=fuzz.trimf(dizziness.universe,[0.1,0.2,0.3])
dizziness['moderate']=fuzz.trimf(dizziness.universe,[0.3,0.5,0.6])
dizziness['severe']=fuzz.trimf(dizziness.universe,[0.6,0.7,0.8])
dizziness['very severe']=fuzz.trimf(dizziness.universe,[0.8,0.9,1])

loss_of_appetite['minor']=fuzz.trimf(loss_of_appetite.universe,[0.1,0.2,0.3])
loss_of_appetite['moderate']=fuzz.trimf(loss_of_appetite.universe,[0.3,0.5,0.6])
loss_of_appetite['severe']=fuzz.trimf(loss_of_appetite.universe,[0.6,0.7,0.8])
loss_of_appetite['very severe']=fuzz.trimf(loss_of_appetite.universe,[0.8,0.9,1])

mp['minor']=fuzz.trimf(mp.universe,[0.1,0.2,0.3])
mp['moderate']=fuzz.trimf(mp.universe,[0.3,0.5,0.6])
mp['severe']=fuzz.trimf(mp.universe,[0.6,0.7,0.8])
mp['very severe']=fuzz.trimf(mp.universe,[0.8,0.9,1])

malaria_fever['minor']=fuzz.trimf(malaria_fever.universe,[0.1,0.2,0.3])
malaria_fever['moderate']=fuzz.trimf(malaria_fever.universe,[0.3,0.5,0.6])
malaria_fever['severe']=fuzz.trimf(malaria_fever.universe,[0.6,0.7,0.8])
malaria_fever['very severe']=fuzz.trimf(malaria_fever.universe,[0.8,0.9,1])

fever.view()
headache.view()
nausea.view()
vomiting.view()
jaundice.view()
enlarge_liver.view()
joint_pain.view()
body_weakness.view()
dizziness.view()
loss_of_appetite.view()
mp.view()
malaria_fever.view()

rule1=ctrl.Rule(fever['minor'] & headache['minor'] & nausea['minor'] & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['minor'] & body_weakness['minor'] & dizziness['severe'] & loss_of_appetite['minor'] & mp['minor'],malaria_fever['minor'])
rule2=ctrl.Rule(fever['moderate'] & headache['minor'] & nausea['minor'] & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['severe'] & loss_of_appetite['severe'] & mp['moderate'],malaria_fever['moderate'])
rule3=ctrl.Rule(fever['severe'] & headache['moderate'] & nausea['minor'] & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['minor'] & body_weakness['severe'] & dizziness['severe'] & loss_of_appetite['severe'] & mp['moderate'],malaria_fever['severe'])
rule4=ctrl.Rule(fever['very severe'] & headache['minor'] & nausea['minor'] & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['severe'] & body_weakness['severe'] & dizziness['minor'] & loss_of_appetite['minor'] & mp['severe'],malaria_fever['very severe'])
rule5=ctrl.Rule(fever['moderate'] & headache['minor'] & nausea['minor'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['moderate'] & loss_of_appetite['severe'] & mp['moderate'],malaria_fever['moderate'])
rule6=ctrl.Rule(fever['minor'] & headache['moderate'] & nausea['moderate'] & vomiting['minor'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['minor'] & body_weakness['minor'] & dizziness['moderate'] & loss_of_appetite['minor'] & mp['minor'],malaria_fever['minor'])
rule7=ctrl.Rule(fever['minor'] & headache['minor'] & nausea['moderate'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['severe'] & body_weakness['severe'] & dizziness['moderate'] & loss_of_appetite['moderate'] & mp['moderate'],malaria_fever['severe'])
rule8=ctrl.Rule(fever['moderate'] & headache['moderate'] & nausea['moderate'] & vomiting['moderate'] & jaundice['moderate'] & enlarge_liver['moderate'] & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['moderate'] & loss_of_appetite['moderate'] & mp['moderate'],malaria_fever['moderate'])
rule9=ctrl.Rule(fever['moderate'] & headache['minor'] & nausea['moderate'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['severe'] & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['severe'] & loss_of_appetite['moderate'] & mp['moderate'],malaria_fever['moderate'])
rule10=ctrl.Rule(fever['minor'] & headache['minor'] & nausea['moderate'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['moderate'] & joint_pain['minor'] & body_weakness['minor'] & dizziness['minor'] & loss_of_appetite['minor'] & mp['minor'],malaria_fever['minor'])
rule11=ctrl.Rule(fever['severe'] & headache['severe'] & nausea['severe'] & vomiting['severe'] & jaundice['severe'] & enlarge_liver['severe'] & joint_pain['severe'] & body_weakness['very severe'] & dizziness['severe'] & loss_of_appetite['severe'] & mp['moderate'],malaria_fever['very severe'])
rule12=ctrl.Rule(fever['moderate'] & headache['severe'] & nausea['moderate'] & vomiting['severe'] & jaundice['moderate'] & enlarge_liver['severe'] & joint_pain['moderate'] & body_weakness['severe'] & dizziness['moderate'] & loss_of_appetite['minor'] & mp['moderate'],malaria_fever['severe'])
rule13=ctrl.Rule(fever['minor'] & headache['moderate'] & nausea['moderate'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['minor'] & body_weakness['moderate'] & dizziness['minor'] & loss_of_appetite['moderate'] & mp['moderate'],malaria_fever['moderate'])
rule14=ctrl.Rule(fever['severe'] & headache['severe'] & nausea['moderate'] & vomiting['severe'] & jaundice['severe'] & enlarge_liver['severe'] & joint_pain['severe'] & body_weakness['severe'] & dizziness['moderate'] & loss_of_appetite['moderate'] & mp['severe'],malaria_fever['severe'])
rule15=ctrl.Rule(fever['minor'] & headache['minor'] & nausea['minor'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['minor'] & body_weakness['severe'] & dizziness['minor'] & loss_of_appetite['severe'] & mp['moderate'],malaria_fever['severe'])
rule16=ctrl.Rule(fever['very severe'] & headache['moderate'] & nausea['minor'] & vomiting['moderate'] & jaundice['severe'] & enlarge_liver['moderate'] & joint_pain['minor'] & body_weakness['very severe'] & dizziness['severe'] & loss_of_appetite['minor'] & mp['moderate'],malaria_fever['very severe'])
rule17=ctrl.Rule(fever['minor'] & headache['very severe'] & nausea['moderate'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['moderate'] & joint_pain['minor'] & body_weakness['moderate'] & dizziness['very severe'] & loss_of_appetite['minor'] & mp['moderate'],malaria_fever['very severe'])
rule18=ctrl.Rule(fever['moderate'] & headache['very severe'] & nausea['very severe'] & vomiting['minor'] & jaundice['severe'] & enlarge_liver['severe'] & joint_pain['moderate'] & body_weakness['severe'] & dizziness['very severe'] & loss_of_appetite['very severe'] & mp['severe'],malaria_fever['very severe'])
rule19=ctrl.Rule(fever['moderate'] & headache['moderate'] & nausea['moderate'] & vomiting['moderate'] & jaundice['minor'] & enlarge_liver['minor'] & joint_pain['moderate'] & body_weakness['moderate'] & dizziness['moderate'] & loss_of_appetite['moderate'] & mp['moderate'],malaria_fever['moderate'])
rule20=ctrl.Rule(fever['very severe'] & headache['severe'] & nausea['severe'] & vomiting['severe'] & jaundice['severe'] & enlarge_liver['severe'] & joint_pain['severe'] & body_weakness['severe'] & dizziness['severe'] & loss_of_appetite['severe'] & mp['moderate'],malaria_fever['very severe'])

malaria_ctrl=ctrl.ControlSystem([rule1,rule2,rule3,rule4,rule5,rule6,rule7,rule8,rule9,rule10,rule11,rule12,rule13,rule14,rule15,rule16,rule17,rule18,rule19,rule20]) #taphopcacluat
malaria_disease=ctrl.ControlSystemSimulation(malaria_ctrl)
malaria_disease.input['fever']= 0.2
malaria_disease.input['headache']=0.1
malaria_disease.input['nausea']=0.25
malaria_disease.input['vomiting']=0.5
malaria_disease.input['jaundice']=0.2
malaria_disease.input['enlarge liver']=0.2
malaria_disease.input['joint pain']=0.2
malaria_disease.input['body weakness']=0.6
malaria_disease.input['dizziness']=0.1
malaria_disease.input['loss of appetite']=0.6
malaria_disease.input['mp']=0.4


malaria_disease.compute()
print(malaria_disease.output['malaria fever'])
malaria_fever.view(sim=malaria_disease)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ae4b872d42a9> in <module>
#     124
#     125
# --> 126 malaria_disease.compute()
#     127 print(malaria_disease.output['malaria fever'])
#     128 malaria_fever.view(sim=malaria_disease)
#
# /usr/local/lib/python3.9/dist-packages/skfuzzy/control/controlsystem.py in compute(self)
#     354         for antecedent in self.ctrl.antecedents:
#     355             if antecedent.input[self] is None:
# --> 356                 raise ValueError("All antecedents must have input values!")
#     357             CrispValueCalculator(antecedent, self).fuzz(antecedent.input[self])
#     358
#
# ValueError: All antecedents must have input values!
