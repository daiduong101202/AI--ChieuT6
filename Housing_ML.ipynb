# %% [markdown]
# <a href="https://colab.research.google.com/github/daiduong101202/AI--ChieuT6/blob/main/Housing_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url='/content/Housing.csv'
data = pd.read_csv(url)
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
correlation=data.corr()
print(correlation)
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
import seaborn as sns
sns.heatmap(correlation, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data)

# %%
from sklearn import linear_model
model=linear_model.LinearRegression()
model.fit(X=pd.DataFrame(data['area']),
          y=data['price'])
print('He so intercept la:',model.intercept_)
print('He so coefficient la:',model.coef_)
model.score(X=pd.DataFrame(data['area']),
          y=data['price'])
# Out:
# He so intercept la: 2387308.48239643
# He so coefficient la: [461.97489427]
# 0.2872931546811469

# %%
y_pred=model.predict(X=pd.DataFrame(data['area']))
data.plot(kind='scatter',x='area',y='price',figsize=(9,9),color='black',xlim=(0,15000))
plt.plot(data['area'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
X=pd.DataFrame([data['area'],data['area']**2]).T
model.fit(X,y=data['price'])
print('Intercept cua mo hinh:',model.intercept_)
print('Coefficient cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(X,y=data['price']))
# Out:
# Intercept cua mo hinh: 795440.7576065883
# Coefficient cua mo hinh: [ 1.03518489e+03 -4.35645185e-02]
# Do chinh xac cua mo hinh: 0.3230746205562587

# %%
import numpy as np
range=np.arange(2000,15000,1000)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='area',y='price',figsize=(9,9), color='black',xlim=(0,15000))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Bac3
model=linear_model.LinearRegression()
X=pd.DataFrame([data['area'],data['area']**2,data['area']**3]).T
model.fit(X,y=data['price'])
print('Intercept cua mo hinh:',model.intercept_)
print('Coefficient cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(X,y=data['price']))
# Out:
# Intercept cua mo hinh: 23332.878579673357
# Coefficient cua mo hinh: [ 1.43801242e+03 -1.03624409e-01  2.57269135e-06]
# Do chinh xac cua mo hinh: 0.32504534381488304

# %%
range=np.arange(2000,15000,1000)
X_range=pd.DataFrame([range,range**2,range**3]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='area',y='price',figsize=(9,9), color='black',xlim=(0,15000))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
#Bac10
model=linear_model.LinearRegression()
X=pd.DataFrame([data['area'],data['area']**2,data['area']**3,data['area']**4,data['area']**5,data['area']**6,data['area']**7,data['area']**8,data['area']**9,data['area']**10 ]).T
model.fit(X,y=data['price'])
print('Intercept cua mo hinh:',model.intercept_)
print('Coefficient cua mo hinh:',model.coef_)
print('Do chinh xac cua mo hinh:',model.score(X,y=data['price']))
# Out:
# Intercept cua mo hinh: 1942004.113154489
# Coefficient cua mo hinh: [ 5.46219207e-05  2.51513295e-01 -3.14386000e-05  1.07565322e-09
#   8.21565038e-15  1.36557432e-14 -2.74502643e-14 -6.63358257e-15
#  -2.63114183e-15  2.20934382e-14]
# Do chinh xac cua mo hinh: 0.3503364718886245

# %%
range=np.arange(2000,15000,1000)
X_range=pd.DataFrame([range,range**2,range**3,range**4, range**5,range**6,range**7,range**8,range**9,range**10]).T
y_pred=model.predict(X=X_range)
data.plot(kind='scatter',x='area',y='price',figsize=(9,9), color='black',xlim=(0,15000))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['area','bedrooms']],y=data['price'])
print('Intercept la:',model.intercept_)
print('Coefficient la:',model.coef_)
print('Do chinh xac:',model.score(X=data.loc[:,['area','bedrooms']],y=data['price']))
# Out:
# Intercept la: 391125.6098772632
# Coefficient la: [4.23778537e+02 7.39565941e+05]
# Do chinh xac: 0.37049285246705077

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['area','bedrooms','bathrooms']],y=data['price'])
print('Intercept la:',model.intercept_)
print('Coefficient la:',model.coef_)
print('Do chinh xac:',model.score(X=data.loc[:,['area','bedrooms','bathrooms']],y=data['price']))
# Out:
# Intercept la: -173171.6076326361
# Coefficient la: [3.78762754e+02 4.06820034e+05 1.38604950e+06]
# Do chinh xac: 0.4870830667058762

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['area','bedrooms','bathrooms','stories']],y=data['price'])
print('Intercept la:',model.intercept_)
print('Coefficient la:',model.coef_)
print('Do chinh xac:',model.score(X=data.loc[:,['area','bedrooms','bathrooms','stories']],y=data['price']))
# Out:
# Intercept la: -282091.2903634589
# Coefficient la: [3.80024429e+02 1.98295494e+05 1.20018047e+06 5.31595009e+05]
# Do chinh xac: 0.5355960442835979

# %%
model=linear_model.LinearRegression()
model.fit(X=data.loc[:,['area','bedrooms','bathrooms','stories','parking']],y=data['price'])
print('Intercept la:',model.intercept_)
print('Coefficient la:',model.coef_)
print('Do chinh xac:',model.score(X=data.loc[:,['area','bedrooms','bathrooms','stories','parking']],y=data['price']))
# Out:
# Intercept la: -145734.4894558806
# Coefficient la: [3.31115495e+02 1.67809788e+05 1.13374016e+06 5.47939810e+05
#  3.77596289e+05]
# Do chinh xac: 0.5615825438679802
